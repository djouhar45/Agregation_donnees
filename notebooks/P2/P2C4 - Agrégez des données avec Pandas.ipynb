# %% [markdown]
# ![openclassrooms](https://s3.eu-west-1.amazonaws.com/course.oc-static.com/courses/6204541/1+HnqdJ-5ofxiPP9HIxdNdpw.jpeg)
#
# # Agrégez des données avec Pandas
#
# Suite aux résultats que vous avez fourni précédemment, le responsable du service prêt revient vous voir avec une remarque : vous l’avez probablement remarqué, mais certains clients ont contracté plusieurs prêts au sein de notre établissement. Cela fausse donc potentiellement les calculs réalisés précédemment.
#
# Il formule donc des demandes additionnelles, auxquelles vous allez devoir répondre en appliquant diverses agrégations.

# %%
import numpy as np
import pandas as pd

# %%
# traitement réalisés précédemment
prets = pd.read_csv('https://raw.githubusercontent.com/OpenClassrooms-Student-Center/fr-4452741-decouvrez-les-librairies-python-pour-la-data-science/main/data/prets.csv')

# calcul du taux d'endettement
prets['taux_endettement'] = round(prets['remboursement'] * 100 / prets['revenu'], 2)

# renommer taux en taux_interet
prets.rename(columns={'taux':'taux_interet'}, inplace=True)

# calculer le cout total du pret
prets['cout_total'] = prets['remboursement'] * prets['duree']

# calculer les bénéfices mensuels réalisés
prets['benefices'] = round((prets['cout_total'] * prets['taux_interet']/100)/(24), 2)

# création d'une variable risque
prets['risque'] = 'Non'
prets.loc[prets['taux_endettement'] > 35, 'risque'] = 'Oui'

prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier  \
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices risque
# 0         1.168             30.80    271212.0     131.99    Non
# 1         3.701              4.52     15360.0      23.69    Non
# 2         1.173             23.50    374355.0     182.97    Non
# 3         0.972             29.50    132609.6      53.71    Non
# 4         1.014             34.80    105485.4      44.57    Non

# %% [markdown]
# Pourriez vous créez un dataframe profil client pour pallier ce problème ?
#
# Par profil client, nous entendons un dataframe où il y n'y a qu'une seule ligne par client, avec le résumé de ses informations (somme remboursement, du taux d'endettement, du cout_total et des bénéfices réalisés)

# %%
prof_clint = prets.groupby('identifiant')[['remboursement', 'taux_endettement', 'cout_total', 'benefices']].sum()
prof_clint.head()
# Out:
#              remboursement  taux_endettement  cout_total  benefices
# identifiant
# 0                  1130.05             30.80    271212.0     131.99
# 1                  1487.85             28.02    389715.0     206.66
# 2                   552.54             29.50    132609.6      53.71
# 3                   586.03             34.80    105485.4      44.57
# 4                   423.61             28.70    101666.4      51.21

# %% [markdown]
# Recalculez le nombre exact de personnes en situation bancaire risquée à partir du taux d'endettemment :

# %%
nbr_pers = prets.loc[prets['taux_endettement']> 35, :]
print(f"le nbr_pers en situation risquée est:{nbr_pers}")
# Out:
# le nbr_pers en situation risquée est:     identifiant      ville     CP  revenu  remboursement  duree        type  \
# 7              6       LYON  69008  1867.0         711.33    240  immobilier
# 8              7       NICE   6000  5486.0        2956.95    300  immobilier
# 10             9  MARSEILLE  13012  1386.0         612.61    180  immobilier
# 15            14   TOULOUSE  31400  2413.0        1334.39    300  immobilier
# 21            20       LYON  69001  3318.0        1237.61    240  immobilier
# 23            22       NICE   6300  5838.0        3018.25    240  immobilier
# 25            24  MARSEILLE  13016  1616.0         602.77    240  immobilier
# 29            28  MARSEILLE  13013  1394.0         535.30    300  immobilier
# 43            42       LYON  69002  2748.0        1393.24    180  immobilier
# 46            45  MARSEILLE  13016  2254.0         865.54    240  immobilier
# 49            48  MARSEILLE  13011  1994.0        1036.88    240  immobilier
# 50            49   TOULOUSE  31100  2931.0        1442.05    240  immobilier
# 52            51  MARSEILLE  13016  1374.0         589.45    120  immobilier
# 53            52  MARSEILLE  13011  2660.0         973.56    300  immobilier
# 54            53       LYON  69006  3706.0        1408.28    240  immobilier
# 61            60  MARSEILLE  13012  1201.0         688.17    240  immobilier
# 69            66  MARSEILLE  13011  1398.0         665.45    300  immobilier
# 70            67      PARIS  75014  5598.0        2395.94    240  immobilier
# 72            69   TOULOUSE  31000  2278.0         872.47    240  immobilier
# 74            71  MARSEILLE  13013  1858.0         687.46    240  immobilier
# 75            72      PARIS  75012  5981.0        2230.91    240  immobilier
# 81            78  MARSEILLE  13011  2818.0        1048.30    240  immobilier
# 85            82   BORDEAUX  33000  3134.0        1131.37    240  immobilier
# 89            85      PARIS  75005  6341.0        2980.27    240  immobilier
# 93            89       LYON  69007  4217.0        1484.38    240  immobilier
# 108          102       LYON  69002  1926.0         951.44    240  immobilier
# 112          106  MARSEILLE  13012  1807.0         746.29    120  immobilier
# 129          122      PARIS  75001  6536.0        2457.54    120  immobilier
# 134          126  MARSEILLE  13003  2668.0        1016.51    120  immobilier
# 135          127       LYON  69008  3208.0        1353.78    300  immobilier
# 138          130  MARSEILLE  13007  2631.0        1473.36    240  immobilier
# 143          134      PARIS  75003  2870.0        1021.72    180  immobilier
# 148          139   BORDEAUX  33300  2239.0         841.86    180  immobilier
# 150          141       NICE   6000  5332.0        1892.86    240  immobilier
# 155          145      PARIS  75017  5978.0        2193.93    300  immobilier
# 167          155       LYON  69001  3831.0        1344.68    180  immobilier
# 168          156   BORDEAUX  33200  2564.0        1151.24    240  immobilier
# 175          162  MARSEILLE  13014  1378.0         497.46    240  immobilier
# 180          167  MARSEILLE  13014  2856.0        1011.02    240  immobilier
# 181          168      PARIS  75003  6366.0        2807.41    240  immobilier
# 183          170      PARIS  75019  2384.0        1311.20    240  immobilier
# 185          172  MARSEILLE  13009  2799.0        1072.02    240  immobilier
# 186          173      PARIS  75006  6784.0        3744.77    180  immobilier
# 187          174  MARSEILLE  13009  1533.0         850.82    180  immobilier
# 195          182      PARIS  75019  4068.0        1505.16    240  immobilier
# 196          183      PARIS  75001  2330.0         871.42    240  immobilier
# 203          190      PARIS  75005  2576.0         984.03    240  immobilier
# 218          204   TOULOUSE  31100  3780.0        1425.06    180  immobilier
# 219          205   BORDEAUX  33100  2835.0        1567.76    180  immobilier
# 220          206       LYON  69005  3798.0        1769.87    240  immobilier
# 221          207       LYON  69001  1881.0         707.26    240  immobilier
# 222          208  MARSEILLE  13011  2547.0         962.77    240  immobilier
# 224          210      PARIS  75016  5846.0        3104.23    180  immobilier
# 227          212      PARIS  75008  4749.0        1766.63    300  immobilier
# 228          213       NICE   6300  2900.0        1392.00    180  immobilier
# 232          217      PARIS  75001  2064.0         825.60    180  immobilier
# 241          225   BORDEAUX  33100  2356.0         876.43    180  immobilier
# 242          226      PARIS  75002  5098.0        2910.96    240  immobilier
#
#      taux_interet  taux_endettement  cout_total  benefices risque
# 7           1.196              38.1    170719.2      85.08    Oui
# 8           1.184              53.9    887085.0     437.63    Oui
# 10          1.284              44.2    110269.8      58.99    Oui
# 15          1.154              55.3    400317.0     192.49    Oui
# 21          1.148              37.3    297026.4     142.08    Oui
# 23          1.229              51.7    724380.0     370.94    Oui
# 25          1.220              37.3    144664.8      73.54    Oui
# 29          1.206              38.4    160590.0      80.70    Oui
# 43          1.209              50.7    250783.2     126.33    Oui
# 46          1.159              38.4    207729.6     100.32    Oui
# 49          1.088              52.0    248851.2     112.81    Oui
# 50          1.200              49.2    346092.0     173.05    Oui
# 52          1.180              42.9     70734.0      34.78    Oui
# 53          1.119              36.6    292068.0     136.18    Oui
# 54          1.161              38.0    337987.2     163.50    Oui
# 61          1.113              57.3    165160.8      76.59    Oui
# 69          1.215              47.6    199635.0     101.07    Oui
# 70          1.136              42.8    575025.6     272.18    Oui
# 72          1.260              38.3    209392.8     109.93    Oui
# 74          1.037              37.0    164990.4      71.29    Oui
# 75          1.150              37.3    535418.4     256.55    Oui
# 81          1.110              37.2    251592.0     116.36    Oui
# 85          1.237              36.1    271528.8     139.95    Oui
# 89          1.074              47.0    715264.8     320.08    Oui
# 93          1.162              35.2    356251.2     172.48    Oui
# 108         1.245              49.4    228345.6     118.45    Oui
# 112         1.193              41.3     89554.8      44.52    Oui
# 129         1.038              37.6    294904.8     127.55    Oui
# 134         1.115              38.1    121981.2      56.67    Oui
# 135         1.134              42.2    406134.0     191.90    Oui
# 138         1.086              56.0    353606.4     160.01    Oui
# 143         1.104              35.6    183909.6      84.60    Oui
# 148         1.248              37.6    151534.8      78.80    Oui
# 150         1.121              35.5    454286.4     212.19    Oui
# 155         1.081              36.7    658179.0     296.45    Oui
# 167         1.097              35.1    242042.4     110.63    Oui
# 168         1.191              44.9    276297.6     137.11    Oui
# 175         1.090              36.1    119390.4      54.22    Oui
# 180         1.153              35.4    242644.8     116.57    Oui
# 181         1.176              44.1    673778.4     330.15    Oui
# 183         1.051              55.0    314688.0     137.81    Oui
# 185         1.171              38.3    257284.8     125.53    Oui
# 186         1.248              55.2    674058.6     350.51    Oui
# 187         1.048              55.5    153147.6      66.87    Oui
# 195         1.080              37.0    361238.4     162.56    Oui
# 196         1.137              37.4    209140.8      99.08    Oui
# 203         1.029              38.2    236167.2     101.26    Oui
# 218         1.251              37.7    256510.8     133.71    Oui
# 219         1.085              55.3    282196.8     127.58    Oui
# 220         1.109              46.6    424768.8     196.28    Oui
# 221         1.270              37.6    169742.4      89.82    Oui
# 222         1.157              37.8    231064.8     111.39    Oui
# 224         1.141              53.1    558761.4     265.64    Oui
# 227         1.077              37.2    529989.0     237.83    Oui
# 228         1.041              48.0    250560.0     108.68    Oui
# 232         1.067              40.0    148608.0      66.07    Oui
# 241         1.172              37.2    157757.4      77.04    Oui
# 242         1.140              57.1    698630.4     331.85    Oui

# %% [markdown]
# Calculez le bénéfice dégagé par chacune de nos agences, par types de prêts. Vous présenterez vos résultats sous la forme d'un tableau simple (via un `group_by`) :

# %%
benifices_deg = prets.groupby(['ville', 'type']).agg({'benefices': 'sum'})
benifices_deg
# Out:
#                       benefices
# ville     type
# BORDEAUX  immobilier    1681.32
# LYON      automobile      47.39
#           immobilier    2967.41
# MARSEILLE automobile      61.36
#           immobilier    4334.55
# NICE      automobile      31.15
#           immobilier    2651.60
# PARIS     automobile      99.50
#           immobilier    9916.85
# TOULOUSE  automobile      61.22
#           immobilier    2076.85

# %% [markdown]
# Pour aller plus loin, on souhaite avoir un tableau à double entrée (via un `pivot_table`) présentant cette fois ci les bénéfices moyen réalisés par chaque agence, pour chaque type de prêt :

# %%
piv_table = prets.pivot_table(index='ville', columns='type', values='benefices', aggfunc='mean')
piv_table
# Out:
# type       automobile  immobilier
# ville
# BORDEAUX          NaN  105.082500
# LYON        15.796667  118.696400
# MARSEILLE   20.453333   60.202083
# NICE        15.575000  139.557895
# PARIS       19.900000  137.734028
# TOULOUSE    20.406667   86.535417

# %% [markdown]
# Quelle ville semble la plus intéressante où développer les prêts immobiliers ?

# %% [markdown]
# Félicitation pour être arrivé au bout ! Voici [la correction correspondante](https://colab.research.google.com/github/OpenClassrooms-Student-Center/fr-4452741-decouvrez-les-librairies-python-pour-la-data-science/blob/main/notebooks/P2/P2C4%20-%20Agr%C3%A9gez%20des%20donn%C3%A9es%20avec%20Pandas%20-%20correction.ipynb).

# %%
piv_table = piv_table.sort_values(by='immobilier', ascending=True)
inters_vill = piv_table.index[0]
print('La ville la plus intéressante est', inters_vill)
# Out:
# La ville la plus intéressante est MARSEILLE
